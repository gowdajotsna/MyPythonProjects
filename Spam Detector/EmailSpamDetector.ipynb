# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm 
spam = pd.read_csv('spam.csv')
input1 = spam['v2']
outputlabel1 = spam["v1"]
z_train, z_test,y_train, y_test = train_test_split(input1,outputlabel1,test_size = 0.2)
print(z_train,y_train)

cv = CountVectorizer()
features = cv.fit_transform(z_train)
print(features)

model = svm.SVC()
model.fit(features,y_train)
print("Accuracy: {}".format(model.score(features,y_train)))

features_test = cv.transform(z_test)
print("Accuracy: {}".format(model.score(features_test,y_test)))
y_pred = model.predict(features_test)  # Predict the labels for the test data
print(len(y_pred))
import pickle
# Creating a pickle file for the CountVectorizer
pickle.dump(cv, open('cv-transform.pkl', 'wb'))
print("Predicted Labels: {}".format(y_pred))  # Print the predicted labels for the test data
inputdata=["I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times."]
inputdatafeaturez = cv.transform(inputdata)
print(inputdatafeaturez)
prediction=model.predict(inputdatafeaturez)
print(prediction)
# Out:
# 2455    Abeg, make profit. But its a start. Are you us...
# 4408    For your chance to WIN a FREE Bluetooth Headse...
# 3199    Just curious because my cuz asked what I was u...
# 2318                            On the way to office da..
# 5240     Gud gud..k, chikku tke care.. sleep well gud nyt
#                               ...
# 3397      It only does simple arithmetic not percentages.
# 1380                               i dnt wnt to tlk wid u
# 3348                               Oh is it! Which brand?
# 5490                              K. I will sent it again
# 2498    I know where the  &lt;#&gt;  is, I'll be there...
# Name: v2, Length: 4457, dtype: object 2455     ham
# 4408    spam
# 3199     ham
# 2318     ham
# 5240     ham
#         ...
# 3397     ham
# 1380     ham
# 3348     ham
# 5490     ham
# 2498     ham
# Name: v1, Length: 4457, dtype: object
#   (0, 747)	1
#   (0, 4296)	1
#   (0, 5383)	1
#   (0, 1575)	1
#   (0, 3742)	1
#   (0, 6384)	1
#   (0, 1050)	1
# ...
